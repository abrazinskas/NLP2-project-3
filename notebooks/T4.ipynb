# %% [markdown]
# We ran the experiments for this model with the same hyperparameters as set in the previous models, although we did reduce the number of epochs to 4 since it took significantly longer to train the VAE than the previous models. We used the mean of the Beta distribution during decoding instead of sampling s from the Kuma distribution, which we do during training. We minimize the negative ELBO.

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# Experiment results.
x = np.arange(4) + 1
train_loss = [11.893875, 2.183947, 1.740678, 1.641281]
val_loss = [11.526319, 7.293943, 6.834830, 6.714286]
train_acc = [0.76, 0.91, 0.92, 0.92]
val_acc = [0.83, 0.85, 0.85, 0.85]
val_aer = [0.86, 0.89, 0.89, 0.88]

# %%
plt.plot(x, train_loss, '-D', label='train')
plt.plot(x, val_loss, '-o', label='validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()
plt.show()

# %%
plt.plot(x, train_acc, '-D', label='train')
plt.plot(x, val_acc, '-o', label='validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()
plt.show()

# %%
plt.plot(x, val_aer, '-o', color='#ff7f01')
plt.xlabel('Epochs')
plt.ylabel('AER')
plt.title('Validation Alignment Error Rate')
plt.show()

# %% [markdown]
# We also ran the final model on the test set and got a test AER 0.88 of and a test accuracy of 0.89. In terms of accuracy the model seems to work really well, and the loss seems to behave as we'd like. In terms of AER, however, we see the same trend as in the previous models, in that it does not really seem to improve. Perhaps this is because of the very limited vocabulary size.
